# %% [markdown]
# # Exploratory Data Analysis of Apps from Google Playstore

# %% [markdown]
# SET THE WORKING DIRECTORY SO THAT WE DO NOT HAVE TO THINK ABOUT THE PATH PROBLEMS

# %%
your_local_path = "C:/Users/mathaaru/Desktop/ai/Dsproject/googleplaystore-acsv/"

# %% [markdown]
# # Import the required modules

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
google_data = pd.read_csv(your_local_path + 'googleplaystore_a.csv')

# %%
print(google_data.shape)
# Out:
# (10779, 13)

# %%
google_data.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# # Inspect and Explore

# %%
google_data.tail(20)
# Out:
#                                                  App             Category  \
# 10759                                        Poop FR               FAMILY
# 10760                                      PLMGSS FR         PRODUCTIVITY
# 10761                                   List iptv FR        VIDEO_PLAYERS
# 10762                                      Cardio-FR              MEDICAL
# 10763                             Naruto & Boruto FR               SOCIAL
# 10764      Frim: get new friends on local chat rooms               SOCIAL
# 10765                             Fr Agnel Ambarnath               FAMILY
# 10766                        Manga-FR - Anime Vostfr               COMICS
# 10767                 Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10768                              News Minecraft.fr   NEWS_AND_MAGAZINES
# 10769                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10770                                       FR Tides              WEATHER
# ...

# %%
google_data.describe()
# Out:
#             Rating       Reviews
# count  9313.000000  1.077900e+04
# mean      4.191592  4.456577e+05
# std       0.515673  2.934946e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.750000e+01
# 50%       4.300000  2.087000e+03
# 75%       4.500000  5.478300e+04
# max       5.000000  7.815831e+07

# %%
google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10779 entries, 0 to 10778
# Data columns (total 13 columns):
# App               10779 non-null object
# Category          10779 non-null object
# Rating            9313 non-null float64
# Reviews           10779 non-null int64
# Size              10779 non-null object
# Installs          10779 non-null object
# Type              10778 non-null object
# Price             10779 non-null object
# Content Rating    10779 non-null object
# Genres            10779 non-null object
# Last Updated      10779 non-null object
# Current Ver       10771 non-null object
# Android Ver       10777 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # Data Cleaning

# %% [raw]
# Count the number of missing values in the data frame

# %%
google_data.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# 5      False     False   False    False  False     False  False  False
# 6      False     False   False    False  False     False  False  False
# 7      False     False   False    False  False     False  False  False
# 8      False     False   False    False  False     False  False  False
# 9      False     False   False    False  False     False  False  False
# 10     False     False   False    False  False     False  False  False
# 11     False     False   False    False  False     False  False  False
# ...

# %%
#count the number of NaN values in each column
print(google_data.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1466
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# # Remove the columns that are 90% empty

# %%
threshold = len(google_data) * 0.1
threshold
# Out:
# 1077.9

# %%
google_data.dropna(thresh=threshold, axis = 1, inplace = True)

# %% [markdown]
# ### Here axis refers to a direction along which aggregation will take place in the matrix , axis =0 refers to row wise aggregation whereas axis =1 refers to column wise aggregation when Inplace=True is passed, the data is renamed in place ie the same cell itself

# %%
# count the number of NaN values in each column
print(google_data.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1466
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# # Data Imputation and Manipulation

# %% [markdown]
# #### Fill the null value cells using appropriate values of the particular column using aggregation function such as mean, median, mode.

# %%
## Define a function impute median
def impute_median(series):
    return series.fillna(series.median())

google_data.Rating=google_data['Rating'].transform(impute_median)

# %%
# count the number of NaN values in each column
print(google_data.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
google_data['Type'].mode().values[0]
# Out:
# 'Free'

# %%
## Fill the missing categorical values with mode

google_data['Type'].fillna(str(google_data['Type'].mode().values[0]),inplace=True)
google_data['Content Rating'].fillna(str(google_data['Content Rating'].mode().values[0]),inplace=True)
google_data['Current Ver'].fillna(str(google_data['Current Ver'].mode().values[0]),inplace=True)
google_data['Android Ver'].fillna(str(google_data['Android Ver'].mode().values[0]),inplace=True)

# %%
# count the number of NaN values in each column
print(google_data.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
## Lets convert both price and Reviews to numerical variables

google_data['Price'] = google_data['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
google_data['Price'] = google_data['Price'].apply(lambda x: float(x))
google_data['Reviews'] = pd.to_numeric(google_data['Reviews'], errors='coerce')

# %%
google_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free    0.0       Everyone
# 1      967   14M     500,000+  Free    0.0       Everyone
# 2    87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3   215644   25M  50,000,000+  Free    0.0           Teen
# 4      967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Distribution of ratings of apps

# %%
google_data['Rating'] = pd.to_numeric(google_data['Rating'], errors = 'coerce')
#rcParams['figure.figsize']=15,6
sns.distplot(google_data['Rating'],kde=False);

# %% [markdown]
# ##### The distribution is highly skewed towards the right which implies there are lesser apps that have a very low rating
# ##### The distribution has high kurtosis inidcating many of the apps are having a rating around 4.1 to 4.5

# %% [markdown]
# # Lets find the highest rated app

# %%
google_data.loc[google_data['Rating'].idxmax()]
# Out:
# App               Hojiboy Tojiboyev Life Hacks
# Category                                COMICS
# Rating                                       5
# Reviews                                     15
# Size                                       37M
# Installs                                1,000+
# Type                                      Free
# Price                                        0
# Content Rating                        Everyone
# Genres                                  Comics
# Last Updated                         26-Jun-18
# Current Ver                                  2
# Android Ver                       4.0.3 and up
# Name: 328, dtype: object

# %% [markdown]
# ##### The highest rated App is 'Hojiboy Tojiboyev Life Hacks' in the category of 'COMICS'

# %% [markdown]
# # Lets analyse the app with maximum number of views

# %%
google_data.loc[google_data['Reviews'].idxmax()]
# Out:
# App                         Facebook
# Category                      SOCIAL
# Rating                           4.1
# Reviews                     78158306
# Size              Varies with device
# Installs              1,000,000,000+
# Type                            Free
# Price                              0
# Content Rating                  Teen
# Genres                        Social
# Last Updated                3-Aug-18
# Current Ver       Varies with device
# Android Ver       Varies with device
# Name: 2526, dtype: object

# %% [markdown]
# ##### The app with maximum number of views is 'Facebook'

# %% [markdown]
# # Lets analyse pricing on apps based on content rating

# %%
#rcParams['figure.figsize'] =20,6
sns.boxplot(x="Content Rating",y= "Rating", hue='Type', data = google_data)

# %% [markdown]
# #### Observation : All the paid apps have a better rating in the content rating groups consisting of "Teen" , "Everyone" ," Mature 17+".

# %%
sns.lmplot('Reviews', # Horizontal axis
            'Rating', # vertical axis
            data=google_data, # data source
            fit_reg=False, # Dont fix a regression line
            hue='Type', # set color
            palette="Paired",
            scatter_kws={"marker":"D",#Set marker style
                          "s":100}) # S marker size

# %%
sns.lmplot('Price', # Horizontal axis
            'Rating', # vertical axis
            data=google_data, # data source
            fit_reg=False, # Dont fix a regression line
            hue='Type', # set color
            palette="Paired",
            scatter_kws={"marker":"D",#Set marker style
                          "s":100}) # S marker size

# %% [markdown]
# #####  Observation: Free Apps have more reviews compared to Paid Apps
